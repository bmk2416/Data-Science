# %% [markdown]
# # FRED data importer and visualizer

# %% [markdown]
# ### Install Dependencies

# %%
# %pip install pandas
# %pip install seaborn
# %pip install fredapi
# Out:
# Requirement already satisfied: pandas in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: seaborn in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (0.11.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.8.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.22.4)
# Requirement already satisfied: pandas>=0.23 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (4.33.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (9.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: fredapi in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (0.5.0)
# Requirement already satisfied: pandas in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from fredapi) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from pandas->fredapi) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from pandas->fredapi) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from pandas->fredapi) (1.22.4)
# Requirement already satisfied: six>=1.5 in c:\users\1 11\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas->fredapi) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from fredapi import Fred
import key

# %% [markdown]
# ### API Authentication

# %%
fred = Fred(key.api_key)

# %% [markdown]
# ### Tester

# %%
fred.search('interest rate')
# Out:
#                               id realtime_start realtime_end  \
# series id
# T10Y2Y                    T10Y2Y     2022-06-28   2022-06-28
# MORTGAGE30US        MORTGAGE30US     2022-06-28   2022-06-28
# T10Y2YM                  T10Y2YM     2022-06-28   2022-06-28
# FEDFUNDS                FEDFUNDS     2022-06-28   2022-06-28
# DFF                          DFF     2022-06-28   2022-06-28
# ...                          ...            ...          ...
# IRSTCI01ITA156N  IRSTCI01ITA156N     2022-06-28   2022-06-28
# LTUIRLTLT01STQ    LTUIRLTLT01STQ     2022-06-28   2022-06-28
# H0RIFSPPCM03NM    H0RIFSPPCM03NM     2022-06-28   2022-06-28
# CRIIRSTCI01STQ    CRIIRSTCI01STQ     2022-06-28   2022-06-28
# CRIIRSTLQ01STM    CRIIRSTLQ01STM     2022-06-28   2022-06-28
#
#                                                              title  \
# series id
# T10Y2Y           10-Year Treasury Constant Maturity Minus 2-Yea...
# MORTGAGE30US     30-Year Fixed Rate Mortgage Average in the Uni...
# T10Y2YM          10-Year Treasury Constant Maturity Minus 2-Yea...
# FEDFUNDS                              Federal Funds Effective Rate
# DFF                                   Federal Funds Effective Rate
# ...                                                            ...
# IRSTCI01ITA156N  Immediate Rates: Less than 24 Hours: Call Mone...
# LTUIRLTLT01STQ   Interest Rates: Long-term government bond yiel...
# H0RIFSPPCM03NM   3-Month Prime Commercial Paper, Average Dealer...
# CRIIRSTCI01STQ   Interest Rates: Immediate rates (< 24 hrs): Li...
# CRIIRSTLQ01STM   Interest Rates: Immediate rates (< 24 hrs): Li...
#
#                 observation_start observation_end                frequency  \
# series id
# T10Y2Y                 1976-06-01      2022-06-27                    Daily
# MORTGAGE30US           1971-04-02      2022-06-23  Weekly, Ending Thursday
# T10Y2YM                1976-06-01      2022-05-01                  Monthly
# FEDFUNDS               1954-07-01      2022-05-01                  Monthly
# DFF                    1954-07-01      2022-06-24             Daily, 7-Day
# ...                           ...             ...                      ...
# IRSTCI01ITA156N        1999-01-01      2021-01-01                   Annual
# LTUIRLTLT01STQ         2001-01-01      2022-01-01                Quarterly
# H0RIFSPPCM03NM         1971-04-01      1997-08-01                  Monthly
# CRIIRSTCI01STQ         1998-01-01      2022-01-01                Quarterly
# CRIIRSTLQ01STM         1998-01-01      2022-04-01                  Monthly
#
#                 frequency_short    units units_short      seasonal_adjustment  \
# series id
# T10Y2Y                        D  Percent           %  Not Seasonally Adjusted
# MORTGAGE30US                  W  Percent           %  Not Seasonally Adjusted
# T10Y2YM                       M  Percent           %  Not Seasonally Adjusted
# FEDFUNDS                      M  Percent           %  Not Seasonally Adjusted
# DFF                           D  Percent           %  Not Seasonally Adjusted
# ...                         ...      ...         ...                      ...
# IRSTCI01ITA156N               A  Percent           %  Not Seasonally Adjusted
# LTUIRLTLT01STQ                Q  Percent           %  Not Seasonally Adjusted
# H0RIFSPPCM03NM                M  Percent           %  Not Seasonally Adjusted
# CRIIRSTCI01STQ                Q  Percent           %  Not Seasonally Adjusted
# CRIIRSTLQ01STM                M  Percent           %  Not Seasonally Adjusted
#
#                 seasonal_adjustment_short               last_updated  \
# series id
# T10Y2Y                                NSA  2022-06-27 16:01:05-05:00
# MORTGAGE30US                          NSA  2022-06-23 11:01:02-05:00
# T10Y2YM                               NSA  2022-06-01 16:01:17-05:00
# FEDFUNDS                              NSA  2022-06-01 15:18:02-05:00
# DFF                                   NSA  2022-06-27 15:17:02-05:00
# ...                                   ...                        ...
# IRSTCI01ITA156N                       NSA  2022-01-18 11:47:03-06:00
# LTUIRLTLT01STQ                        NSA  2022-05-12 09:09:09-05:00
# H0RIFSPPCM03NM                        NSA  2022-06-03 16:09:34-05:00
# CRIIRSTCI01STQ                        NSA  2022-06-14 11:03:57-05:00
# CRIIRSTLQ01STM                        NSA  2022-06-14 11:46:07-05:00
#
#                 popularity                                              notes
# series id
# T10Y2Y                 100  Starting with the update on June 21, 2019, the...
# MORTGAGE30US            99  Data is provided "as is," by Freddie Mac® with...
# T10Y2YM                 54  Series is calculated as the spread between 10-...
# FEDFUNDS                96  Averages of daily figures.   For additional hi...
# DFF                     84  For additional historical federal funds rate d...
# ...                    ...                                                ...
# IRSTCI01ITA156N          1  OECD descriptor ID: IRSTCI01 OECD unit ID: ST ...
# LTUIRLTLT01STQ           1  OECD descriptor ID: IRLTLT01 OECD unit ID: ST ...
# H0RIFSPPCM03NM           1  Averages of daily figures.  The Federal Reserv...
# CRIIRSTCI01STQ           1  OECD descriptor ID: IRSTCI01 OECD unit ID: ST ...
# CRIIRSTLQ01STM           1  OECD descriptor ID: IRSTLQ01 OECD unit ID: ST ...
#
# [1000 rows x 15 columns]

# %% [markdown]
# ### Import Data

# %%
data = fred.get_series('FF')
#! TODO add Fed Balance sheet data

# %% [markdown]
# ### Display

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(25,15))
plt.title('Fed Funds Rate')
sns.lineplot(data=data, err_style='bars')
# Out:
# <AxesSubplot:title={'center':'Fed Funds Rate'}>
